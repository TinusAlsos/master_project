# %%
# Import python modules
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Determine the absolute path to the src directory (one level up from notebooks)
module_path = os.path.abspath(os.path.join("..", "src"))
if module_path not in sys.path:
    sys.path.append(module_path)

project_root = os.path.abspath(os.path.join(".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# Now this works because Python sees `src` as a top-level module
from src import analytics, plotting, utils

# %%
import yaml

# %%
# TODO: Read both no_bat and bat results. Make a copy of the config with co2-prices

# %%
BASE_FOLDER = os.path.dirname(os.getcwd())
RUNS_FOLDER = os.path.join(BASE_FOLDER, "runs")
BATCH_RUNS_FOLDER = os.path.join(RUNS_FOLDER, "batch_runs")

DATA_FOLDER = os.path.join(BASE_FOLDER, "data")

# %%
configs_to_modify = ["config_128_sv1_8_weeks_season"]
expansion_factors = [0.25, 0.50, 0.75]
suffixes = ["_ef025", "_ef050", "_ef075"]

# %%
for i, config in enumerate(configs_to_modify):
    for j in range(len(expansion_factors)):
        # Read the config file
        suffix = suffixes[j]
        expansion_factor = expansion_factors[j]
        overwrite_dict = {"expansion_factor": expansion_factor}
        utils.copy_and_modify_config(
            config_name_or_path=config, suffix=suffix, overwrite_dict=overwrite_dict
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i, config in enumerate(configs_to_modify):
# ----> 2     for j in range(len(expansion_factors)):
#       3         # Read the config file
#       4         suffix = suffixes[j]
#       5         expansion_factor = expansion_factors[j]
#
# NameError: name 'expansion_factors' is not defined

# %% [markdown]
# # Setup ramping limit configs

# %%
configs_to_modify = ["config_128_sv2_4_weeks_ef05_ramping"]
ramping_limits = [0.25, 0.50, 1.0]
suffixes = ["_ramp025", "_ramp050", "_ramp100"]

# %%
for i, config in enumerate(configs_to_modify):
    for j in range(len(ramping_limits)):
        # Read the config file
        suffix = suffixes[j]
        ramping_limit = ramping_limits[j]
        overwrite_dict = {"ramping_limit": ramping_limit}
        utils.copy_and_modify_config(
            config_name_or_path=config, suffix=suffix, overwrite_dict=overwrite_dict
        )
# Out:
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv2_4_weeks_ef05_ramping_ramp025.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv2_4_weeks_ef05_ramping_ramp050.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv2_4_weeks_ef05_ramping_ramp100.yaml

# %% [markdown]
# # Setup yearly_discount_configs

# %%
configs_to_modify = ["config_128_sv1_4_weeks_ef05"]
yearly_discounts = [10, 50, 100, 250, 500]
suffixes = ["_dc10", "_dc50", "_dc100", "_dc250", "_dc500"]

# %%
for i, config in enumerate(configs_to_modify):
    for j in range(len(yearly_discounts)):
        # Read the config file
        suffix = suffixes[j]
        yearly_discount = yearly_discounts[j]
        overwrite_dict = {"yearly_discount": yearly_discount}
        utils.copy_and_modify_config(
            config_name_or_path=config, suffix=suffix, overwrite_dict=overwrite_dict
        )
# Out:
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv1_4_weeks_ef05_dc10.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv1_4_weeks_ef05_dc50.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv1_4_weeks_ef05_dc100.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv1_4_weeks_ef05_dc250.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv1_4_weeks_ef05_dc500.yaml

# %%
configs_to_modify = [
    "config_128_sv2_8_weeks_ef05_rf025",
    "config_128_sv2_8_weeks_ef05_rf025_no_bat",
]
suffixes = ["___"]
suffix = suffixes[0]

# %%
for i, config in enumerate(configs_to_modify):
    overwrite_dict = {
        "VSS": True,
        "ESPI:": True,
    }
    utils.copy_and_modify_config(
        config_name_or_path=config, suffix=suffix, overwrite_dict=overwrite_dict
    )
# Out:
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv2_8_weeks_ef05_rf025___.yaml
# New config saved to: c:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\configs\models\config_128_sv2_8_weeks_ef05_rf025_no_bat___.yaml
