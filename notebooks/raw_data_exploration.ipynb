# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import sys

# %%
# Determine the absolute path to the src directory (one level up from notebooks)
module_path = os.path.abspath(os.path.join("..", "src"))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import plotting
import utils

# %%
from pypsa import Network

# %%
networks_folder = (
    r"C:\Users\tinus\OneDrive\Dokumenter\0 Master\code\master_project\data\raw\networks"
)
networks_path = os.path.join(networks_folder, "elec_s_37.nc")

# %%
network = Network(networks_path)
network.generators.loc[:, "p_nom_extendable"].describe()
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v0.22.1 while current version is v0.31.1. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.io:Imported network elec_s_37.nc has buses, carriers, generators, lines, links, loads, storage_units
# count      284
# unique       2
# top       True
# freq       145
# Name: p_nom_extendable, dtype: object

# %%
network.generators.columns
# Out:
# Index(['bus', 'control', 'type', 'p_nom', 'p_nom_mod', 'p_nom_extendable',
#        'p_nom_min', 'p_nom_max', 'p_min_pu', 'p_max_pu', 'p_set', 'e_sum_min',
#        'e_sum_max', 'q_set', 'sign', 'carrier', 'marginal_cost',
#        'marginal_cost_quadratic', 'active', 'build_year', 'lifetime',
#        'capital_cost', 'efficiency', 'committable', 'start_up_cost',
#        'shut_down_cost', 'stand_by_cost', 'min_up_time', 'min_down_time',
#        'up_time_before', 'down_time_before', 'ramp_limit_up',
#        'ramp_limit_down', 'ramp_limit_start_up', 'ramp_limit_shut_down',
#        'weight', 'p_nom_opt'],
#       dtype='object')

# %%
network.lines.columns
# Out:
# Index(['bus0', 'bus1', 'type', 'x', 'r', 'g', 'b', 's_nom', 's_nom_mod',
#        's_nom_extendable', 's_nom_min', 's_nom_max', 's_max_pu',
#        'capital_cost', 'active', 'build_year', 'lifetime', 'length', 'carrier',
#        'terrain_factor', 'num_parallel', 'v_ang_min', 'v_ang_max',
#        'sub_network', 'x_pu', 'r_pu', 'g_pu', 'b_pu', 'x_pu_eff', 'r_pu_eff',
#        's_nom_opt'],
#       dtype='object')

# %%
network.lines["extebdable"] = 3.5
network.lines["extebdable"].describe()
# Out:
# count    52.0
# mean      3.5
# std       0.0
# min       3.5
# 25%       3.5
# 50%       3.5
# 75%       3.5
# max       3.5
# Name: extebdable, dtype: float64

# %%
network.lines["extendable"] = np.random.choice([True, False], size=len(network.lines))
network.lines["extendable"]
# Out:
# Line
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29     True
# 30     True
# 31     True
# 32    False
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38     True
# 39     True
# 40    False
# 41    False
# 42     True
# 43     True
# 44    False
# 45     True
# 46    False
# 47     True
# 48    False
# 49    False
# 50    False
# 51    False
# 52     True
# Name: extendable, dtype: bool

# %%
network.lines["extension_potential"] = (
    np.random.uniform(0, 1, size=len(network.lines)) * 1000
)

# %%
network.lines["extension_potential"]
# Out:
# Line
# 1     306.363532
# 2     221.957884
# 3     387.971258
# 4     936.383650
# 5     975.995422
# 6     672.383676
# 7     902.834109
# 8     845.750871
# 9     377.994041
# 10     92.217009
# 11    653.410903
# 12    557.840762
# 13    361.564763
# 14    225.054505
# 15    406.519916
# 16    468.940249
# 17    269.235578
# 18    291.792774
# 19    457.686399
# 20    860.533913
# 21    586.252904
# 22    283.487862
# 23    277.977507
# 24    454.622076
# 25    205.410345
# 26    201.378711
# 27    514.035060
# 28     87.229369
# 29    483.585532
# 30    362.176212
# 31    707.686622
# 32    746.746223
# 33    691.092922
# 34    689.180414
# 35    373.600124
# 36    668.134805
# 37    339.848664
# 38    572.793870
# 39    325.807158
# 40    445.145049
# 41     61.528931
# 42    242.675422
# 43    971.602606
# 44    230.584204
# 45    691.477511
# 46    650.476858
# 47    723.939139
# 48    475.088611
# 49    596.663775
# 50     66.969424
# 51     72.562138
# 52    198.976026
# ...

# %%
network.lines["test"] = (
    network.lines["extension_potential"] * network.lines["extendable"] * 0.2
)

# %%
network.lines["test"]
# Out:
# Line
# 1      61.272706
# 2      44.391577
# 3       0.000000
# 4       0.000000
# 5     195.199084
# 6     134.476735
# 7     180.566822
# 8       0.000000
# 9       0.000000
# 10      0.000000
# 11    130.682181
# 12      0.000000
# 13      0.000000
# 14      0.000000
# 15     81.303983
# 16      0.000000
# 17      0.000000
# 18     58.358555
# 19     91.537280
# 20    172.106783
# 21    117.250581
# 22      0.000000
# 23      0.000000
# 24     90.924415
# 25     41.082069
# 26     40.275742
# 27      0.000000
# 28     17.445874
# 29     96.717106
# 30     72.435242
# 31    141.537324
# 32      0.000000
# 33    138.218584
# 34      0.000000
# 35      0.000000
# 36    133.626961
# 37      0.000000
# 38    114.558774
# 39     65.161432
# 40      0.000000
# 41      0.000000
# 42     48.535084
# 43    194.320521
# 44      0.000000
# 45    138.295502
# 46      0.000000
# 47    144.787828
# 48      0.000000
# 49      0.000000
# 50      0.000000
# 51      0.000000
# 52     39.795205
# ...
