# %%
import os


def print_folder_structure(startpath):
    for root, dirs, files in os.walk(startpath):
        # Filter out hidden directories and files
        dirs[:] = [d for d in dirs if not d.startswith(".")]
        files = [f for f in files if not f.startswith(".")]

        level = root.replace(startpath, "").count(os.sep)
        indent = " " * 4 * level
        print(f"{indent}{os.path.basename(root)}/")
        subindent = " " * 4 * (level + 1)
        for file in files:
            print(f"{subindent}{file}")

# %%
# Get the current working directory
current_folder = os.getcwd()

# Call the function to print the folder structure
print_folder_structure(current_folder)
# Out:
# master_project/
#     readme.md
#     testing.ipynb
#     __init__.py
#     configs/
#         base_config.yaml
#         models/
#             base_config.yaml
#             config_small.yaml
#             config_small_2.yaml
#             config_test.yaml
#         preprocessing/
#             base_config.yaml
#             config_all.yaml
#             config_Iberia.yaml
#             config_small.yaml
#             battery/
#                 base_config.yaml
#     data/
#         countries/
#             ne_110m_admin_0_countries.cpg
#             ne_110m_admin_0_countries.dbf
#             ne_110m_admin_0_countries.prj
#             ne_110m_admin_0_countries.README.html
#             ne_110m_admin_0_countries.shp
#             ne_110m_admin_0_countries.shx
#             ne_110m_admin_0_countries.VERSION.txt
#         processed/
#             elec_s_128_ES_PT/
#                 batteries.csv
#                 branches.csv
#                 capacity_factors.csv
#                 config.yaml
#                 generators.csv
#                 generator_costs.csv
#                 hourly_demand.csv
#                 nodes.csv
#                 analyzed_data/
#                     bar_effective_capacity_generators.png
#                     bar_generators_installed_capacity.png
#                     grid_battery_cases.png
#                     grid_lines_with_sizes.png
#                     grid_simple.png
#                     grid_sized_generators.png
#                     grid_sized_generators_and_lines.png
#                     grid_with_ids.png
#                     grid_with_line_sizes_and_extensions.png
#                     table_branches_overview.csv
#                     table_generators_costs_and_emissions.csv
#                     table_generators_overview.csv
#                     capacity_factors/
#                         average_hourly_capacity_factors_with_std.png
#                         average_monthly_capacity_factors_with_std.png
#                         average_weekly_capacity_factors.png
#                         correlation_matrix_offwind-ac.png
#                         correlation_matrix_onwind.png
#                         correlation_matrix_ror.png
#                         correlation_matrix_solar.png
#                         offwind-ac_average_hourly_capacity_factors_with_std.png
#                         offwind-ac_average_monthly_capacity_factors_with_std.png
#                         offwind-ac_heatmap_capacity_factors.png
#                         offwind-ac_time_series_capacity_factors.png
#                         onwind_average_hourly_capacity_factors_with_std.png
#                         onwind_average_monthly_capacity_factors_with_std.png
#                         onwind_heatmap_capacity_factors.png
#                         onwind_time_series_capacity_factors.png
#                         ror_average_hourly_capacity_factors_with_std.png
#                         ror_average_monthly_capacity_factors_with_std.png
#                         ror_heatmap_capacity_factors.png
#                         ror_time_series_capacity_factors.png
#                         solar_average_hourly_capacity_factors_with_std.png
#                         solar_average_monthly_capacity_factors_with_std.png
#                         solar_heatmap_capacity_factors.png
#                         solar_time_series_capacity_factors.png
#                         time_series_capacity_factors.png
#                     demand/
#                         grid_demand_daily.png
#                         grid_demand_network_hourly.png
#                         plot_aggregated_average_hourly_demand_with_stds.png
#                         plot_average_hourly_demand_each_month_aggregated.png
#                         plot_average_hourly_demand_each_month_ES1 1.png
#                         plot_average_hourly_demand_each_season_aggregated.png
#                         plot_normalized_demand_hourly_country.png
#             elec_s_37_ES_PT/
#                 batteries.csv
#                 branches.csv
#                 capacity_factors.csv
#                 config.yaml
#                 generators.csv
#                 generator_costs.csv
#                 hourly_demand.csv
#                 nodes.csv
#                 analyzed_data/
#                     bar_effective_capacity_generators.png
#                     bar_generators_installed_capacity.png
#                     grid_battery_cases.png
#                     grid_lines_with_sizes.png
#                     grid_simple.png
#                     grid_sized_generators.png
#                     grid_sized_generators_and_lines.png
#                     grid_with_ids.png
#                     grid_with_line_sizes_and_extensions.png
#                     table_branches_overview.csv
#                     table_generators_costs_and_emissions.csv
#                     table_generators_overview.csv
#                     table_genertable_generators_costs_and_emissionsators_methodology.csv
#                     capacity_factors/
#                         average_hourly_capacity_factors_with_std.png
#                         average_monthly_capacity_factors_with_std.png
#                         average_weekly_capacity_factors.png
#                         correlation_matrix_offwind-ac.png
#                         correlation_matrix_onwind.png
#                         correlation_matrix_ror.png
#                         correlation_matrix_solar.png
#                         offwind-ac_average_hourly_capacity_factors_with_std.png
#                         offwind-ac_average_monthly_capacity_factors_with_std.png
#                         offwind-ac_heatmap_capacity_factors.png
#                         offwind-ac_time_series_capacity_factors.png
#                         onwind_average_hourly_capacity_factors_with_std.png
#                         onwind_average_monthly_capacity_factors_with_std.png
#                         onwind_heatmap_capacity_factors.png
#                         onwind_time_series_capacity_factors.png
#                         ror_average_hourly_capacity_factors_with_std.png
#                         ror_average_monthly_capacity_factors_with_std.png
#                         ror_heatmap_capacity_factors.png
#                         ror_time_series_capacity_factors.png
#                         solar_average_hourly_capacity_factors_with_std.png
#                         solar_average_monthly_capacity_factors_with_std.png
#                         solar_heatmap_capacity_factors.png
#                         solar_time_series_capacity_factors.png
#                         time_series_capacity_factors.png
#                     demand/
#                         grid_demand_daily.png
#                         grid_demand_network_hourly.png
#                         plot_aggregated_average_hourly_demand_with_stds.png
#                         plot_average_hourly_demand_each_month_aggregated.png
#                         plot_average_hourly_demand_each_month_ES1 0.png
#                         plot_average_hourly_demand_each_season_aggregated.png
#                         plot_normalized_demand_hourly_country.png
#         raw/
#             networks/
#                 base.nc
#                 elec.nc
#                 elec_s.nc
#                 elec_s_1024.nc
#                 elec_s_1024_ec.nc
#                 elec_s_128.nc
#                 elec_s_128_ec.nc
#                 elec_s_128_ec_lcopt_Co2L-3H.nc
#                 elec_s_256.nc
#                 elec_s_256_ec.nc
#                 elec_s_256_ec_lcopt_Co2L-3H.nc
#                 elec_s_37.nc
#                 elec_s_37_ec.nc
#                 elec_s_37_ec_lcopt_Co2L-3H.nc
#                 elec_s_512.nc
#                 elec_s_512_ec.nc
#             resources/
#                 busmap_elec_s.csv
#                 busmap_elec_s_1024.csv
#                 busmap_elec_s_128.csv
#                 busmap_elec_s_256.csv
#                 busmap_elec_s_37.csv
#                 busmap_elec_s_512.csv
#                 connection_costs_s.csv
#                 costs.csv
#                 country_shapes.geojson
#                 europe_shape.geojson
#                 linemap_elec_s_1024.csv
#                 linemap_elec_s_128.csv
#                 linemap_elec_s_256.csv
#                 linemap_elec_s_37.csv
#                 linemap_elec_s_512.csv
#                 load.csv
#                 natura.tiff
#                 nuts3_shapes.geojson
#                 offshore_shapes.geojson
#                 powerplants.csv
#                 profile_hydro.nc
#                 profile_offwind-ac.nc
#                 profile_offwind-dc.nc
#                 profile_onwind.nc
#                 profile_solar.nc
#                 regions_offshore.geojson
#                 regions_offshore_elec_s.geojson
#                 regions_offshore_elec_s_1024.geojson
#                 regions_offshore_elec_s_128.geojson
#                 regions_offshore_elec_s_256.geojson
#                 regions_offshore_elec_s_37.geojson
#                 regions_offshore_elec_s_512.geojson
#                 regions_onshore.geojson
#                 regions_onshore_elec_s.geojson
#                 regions_onshore_elec_s_1024.geojson
#                 regions_onshore_elec_s_128.geojson
#                 regions_onshore_elec_s_256.geojson
#                 regions_onshore_elec_s_37.geojson
#                 regions_onshore_elec_s_512.geojson
#                 shipdensity_raster.nc
#     figures/
#     master_project/
#         LICENSE
#         README.md
#     notebooks/
#         analyze_input_data.ipynb
#         analyze_results.ipynb
#         run_development.ipynb
#     results/
#     runs/
#         batch_runs/
#             1_GTSEP_v0-test small-Feb13_Thu_h09/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#                 model_info/
#                     config.yaml
#                     model.mps
#                     model_info.csv
#                     solution.sol
#                 results/
#                     figures/
#                         bar_effective_capacity_generators.png
#                         bar_monthly_production.png
#                         grid_congestion_network_congestion.png
#                         grid_congestion_network_utilization.png
#                         grid_simple.png
#                         batteries/
#                             10_plot_battery_average_hourly_soc_month_.png
#                             11_plot_battery_average_hourly_soc_month_.png
#                             12_plot_battery_average_hourly_soc_month_.png
#                             1_plot_battery_average_hourly_soc_month_.png
#                             2_plot_battery_average_hourly_soc_month_.png
#                             3_plot_battery_average_hourly_soc_month_.png
#                             4_plot_battery_average_hourly_soc_month_.png
#                             5_plot_battery_average_hourly_soc_month_.png
#                             6_plot_battery_average_hourly_soc_month_.png
#                             7_plot_battery_average_hourly_soc_month_.png
#                             8_plot_battery_average_hourly_soc_month_.png
#                             9_plot_battery_average_hourly_soc_month_.png
#                             cake_battery_usage_per_battery_per_month.png
#                             Murcia_plot_battery_average_hourly_soc_by_month_.png
#                             plot_battery_average_hourly_soc_per_battery.png
#                             plot_num_cycles_per_month.png
#                             Porto_plot_battery_average_hourly_soc_by_month_.png
#                     tables/
#                         table_branches_overview.csv
#                         table_cost_breakdown.csv
#                         table_generators_overview.csv
#                         table_generators_production_breakdown.csv
#             2_GTSEP_v0-test small 2-Feb13_Thu_h09/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#                 model_info/
#                     config.yaml
#                     model.mps
#                     model_info.csv
#                     solution.sol
#                 results/
#                     figures/
#                         bar_effective_capacity_generators.png
#                         bar_monthly_production.png
#                         grid_congestion_network_congestion.png
#                         grid_congestion_network_utilization.png
#                         grid_simple.png
#                         batteries/
#                             10_plot_battery_average_hourly_soc_month_.png
#                             11_plot_battery_average_hourly_soc_month_.png
#                             12_plot_battery_average_hourly_soc_month_.png
#                             1_plot_battery_average_hourly_soc_month_.png
#                             2_plot_battery_average_hourly_soc_month_.png
#                             3_plot_battery_average_hourly_soc_month_.png
#                             4_plot_battery_average_hourly_soc_month_.png
#                             5_plot_battery_average_hourly_soc_month_.png
#                             6_plot_battery_average_hourly_soc_month_.png
#                             7_plot_battery_average_hourly_soc_month_.png
#                             8_plot_battery_average_hourly_soc_month_.png
#                             9_plot_battery_average_hourly_soc_month_.png
#                             cake_battery_usage_per_battery_per_month.png
#                             Murcia_plot_battery_average_hourly_soc_by_month_.png
#                             plot_battery_average_hourly_soc_per_battery.png
#                             plot_num_cycles_per_month.png
#                             Porto_plot_battery_average_hourly_soc_by_month_.png
#                     tables/
#                         table_branches_overview.csv
#                         table_cost_breakdown.csv
#                         table_generators_overview.csv
#                         table_generators_production_breakdown.csv
#         single_runs/
#             GTSEP_v0-test small 2-Feb13_Thu_h09/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#                 model_info/
#                     config.yaml
#                     model.mps
#                     model_info.csv
#                     solution.sol
#                 results/
#                     figures/
#                         bar_effective_capacity_generators.png
#                         bar_monthly_production.png
#                         grid_congestion_network_congestion.png
#                         grid_congestion_network_utilization.png
#                         grid_simple.png
#                         batteries/
#                             10_plot_battery_average_hourly_soc_month_.png
#                             11_plot_battery_average_hourly_soc_month_.png
#                             12_plot_battery_average_hourly_soc_month_.png
#                             1_plot_battery_average_hourly_soc_month_.png
#                             2_plot_battery_average_hourly_soc_month_.png
#                             3_plot_battery_average_hourly_soc_month_.png
#                             4_plot_battery_average_hourly_soc_month_.png
#                             5_plot_battery_average_hourly_soc_month_.png
#                             6_plot_battery_average_hourly_soc_month_.png
#                             7_plot_battery_average_hourly_soc_month_.png
#                             8_plot_battery_average_hourly_soc_month_.png
#                             9_plot_battery_average_hourly_soc_month_.png
#                             cake_battery_usage_per_battery_per_month.png
#                             Murcia_plot_battery_average_hourly_soc_by_month_.png
#                             plot_battery_average_hourly_soc_per_battery.png
#                             plot_num_cycles_per_month.png
#                             Porto_plot_battery_average_hourly_soc_by_month_.png
#                     tables/
#                         table_branches_overview.csv
#                         table_cost_breakdown.csv
#                         table_generators_overview.csv
#                         table_generators_production_breakdown.csv
#             GTSEP_v0-test small-Feb11_Tue_h08/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#             GTSEP_v0-test small-Feb11_Tue_h09/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#                 model_info/
#                     config.yaml
#                     model.mps
#                     model_info.csv
#                     solution.sol
#                 results/
#             GTSEP_v0-test small-Feb11_Tue_h10/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#                 model_info/
#                     config.yaml
#                     model.mps
#                     model_info.csv
#                     solution.sol
#                 results/
#                     figures/
#                         bar_effective_capacity_generators.png
#                         bar_monthly_production.png
#                         grid_congestion_network_congestion.png
#                         grid_congestion_network_utilization.png
#                         grid_simple.png
#                         batteries/
#                             10plot_battery_average_hourly_soc_month_.png
#                             10_plot_battery_average_hourly_soc_month_.png
#                             11plot_battery_average_hourly_soc_month_.png
#                             11_plot_battery_average_hourly_soc_month_.png
#                             12plot_battery_average_hourly_soc_month_.png
#                             12_plot_battery_average_hourly_soc_month_.png
#                             1plot_battery_average_hourly_soc_month_.png
#                             1_plot_battery_average_hourly_soc_month_.png
#                             2plot_battery_average_hourly_soc_month_.png
#                             2_plot_battery_average_hourly_soc_month_.png
#                             3plot_battery_average_hourly_soc_month_.png
#                             3_plot_battery_average_hourly_soc_month_.png
#                             4plot_battery_average_hourly_soc_month_.png
#                             4_plot_battery_average_hourly_soc_month_.png
#                             5plot_battery_average_hourly_soc_month_.png
#                             5_plot_battery_average_hourly_soc_month_.png
#                             6plot_battery_average_hourly_soc_month_.png
#                             6_plot_battery_average_hourly_soc_month_.png
#                             7plot_battery_average_hourly_soc_month_.png
#                             7_plot_battery_average_hourly_soc_month_.png
#                             8plot_battery_average_hourly_soc_month_.png
#                             8_plot_battery_average_hourly_soc_month_.png
#                             9plot_battery_average_hourly_soc_month_.png
#                             9_plot_battery_average_hourly_soc_month_.png
#                             cake_battery_usage_per_battery_per_month.png
#                             Murciaplot_battery_average_hourly_soc_by_month_.png
#                             Murcia_plot_battery_average_hourly_soc_by_month_.png
#                             plot_battery_average_hourly_soc_per_battery.png
#                             plot_num_cycles_per_month.png
#                             Portoplot_battery_average_hourly_soc_by_month_.png
#                             Porto_plot_battery_average_hourly_soc_by_month_.png
#                     tables/
#                         table_branches_overview.csv
#                         table_cost_breakdown.csv
#                         table_generators_overview.csv
#                         table_generators_production_breakdown.csv
#             GTSEP_v0-test small-Feb13_Thu_h09/
#                 decision_variables/
#                     battery_build.csv
#                     battery_charging.csv
#                     battery_discharging.csv
#                     battery_soc.csv
#                     branch_build.csv
#                     branch_capacity.csv
#                     curtailment.csv
#                     generation.csv
#                     generator_build.csv
#                     generator_capacity.csv
#                     load_shedding.csv
#                     power_flow.csv
#                 model_info/
#                     config.yaml
#                     model.mps
#                     model_info.csv
#                     solution.sol
#                 results/
#                     figures/
#                         bar_effective_capacity_generators.png
#                         bar_monthly_production.png
#                         grid_congestion_network_congestion.png
#                         grid_congestion_network_utilization.png
#                         grid_simple.png
#                         batteries/
#                             10_plot_battery_average_hourly_soc_month_.png
#                             11_plot_battery_average_hourly_soc_month_.png
#                             12_plot_battery_average_hourly_soc_month_.png
#                             1_plot_battery_average_hourly_soc_month_.png
#                             2_plot_battery_average_hourly_soc_month_.png
#                             3_plot_battery_average_hourly_soc_month_.png
#                             4_plot_battery_average_hourly_soc_month_.png
#                             5_plot_battery_average_hourly_soc_month_.png
#                             6_plot_battery_average_hourly_soc_month_.png
#                             7_plot_battery_average_hourly_soc_month_.png
#                             8_plot_battery_average_hourly_soc_month_.png
#                             9_plot_battery_average_hourly_soc_month_.png
#                             cake_battery_usage_per_battery_per_month.png
#                             Murcia_plot_battery_average_hourly_soc_by_month_.png
#                             plot_battery_average_hourly_soc_per_battery.png
#                             plot_num_cycles_per_month.png
#                             Porto_plot_battery_average_hourly_soc_by_month_.png
#                     tables/
#                         table_branches_overview.csv
#                         table_cost_breakdown.csv
#                         table_generators_overview.csv
#                         table_generators_production_breakdown.csv
#     src/
#         analytics.py
#         models.py
#         plotting.py
#         preprocessing.py
#         run.py
#         run_batches.py
#         utils.py
#         __init__.py
#         __pycache__/
#             analytics.cpython-312.pyc
#             models.cpython-312.pyc
#             plotting.cpython-312.pyc
#             preprocessing.cpython-312.pyc
#             run.cpython-312.pyc
#             run_batches.cpython-312.pyc
#             utils.cpython-312.pyc
#             __init__.cpython-312.pyc

# %%
import os
from typing import Union


def count_png_files(folder_path: str) -> int:
    """
    Counts the number of .png files in a nested directory structure.

    Parameters:
        folder_path (str): The path to the root folder.

    Returns:
        int: The total number of .png files found within the folder and its subdirectories.
    """
    count = 0
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # Check file extension in a case-insensitive manner
            if file.lower().endswith(".png"):
                count += 1
    return count

# %%
path = "C:\\Users\\tinus\\OneDrive\\Dokumenter\\0 Master\\code\\master_project\\data\\processed\\elec_s_128_ES_PT\\analyzed_data"

count_png_files(path)
# Out:
# 40
